# %% [markdown]
# # Gemma 2 2B QLoRA fine-tune for NL → Vega-Lite
#
# Runs on the free Colab T4 tier. Expects a curated nvBench split at `data/nvbench_train.jsonl` (mount Drive or upload).
#
# Outputs: a LoRA adapter saved to Drive or pushed to the Hugging Face Hub.

# %%
# Install training dependencies
# !pip install -q transformers peft trl bitsandbytes accelerate datasets

# %% [markdown]
# ## TODO
#
# - Load curated nvBench split
# - Configure `BitsAndBytesConfig` for 4-bit
# - Apply LoRA via `peft`
# - Train with `SFTTrainer`
# - Save adapter to Drive or push to Hub
